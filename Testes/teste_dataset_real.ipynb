# %% [markdown]
# # Teste de PCA com `crosstab` de países tranposta

# %%
import pandas as pd
from sklearn.decomposition import PCA
import numpy as np

# %%
df = pd.read_csv("/home/vortex/Documents/Fatec/Trabalhos/Projeto Integrador local/BD/Scripts/ANTAQ/Exportação por país/exp_pais_2018.csv")

# %%
df
# Out:
#                                              Mercadoria          AE  \
# 0                     Cavalos, asininos e muares, vivos     0.00100
# 1                       Animais vivos da espécie bovina     0.00200
# 2            Animais vivos das espécies ovina e caprina     0.00100
# 3                                  Outros animais vivos     0.00100
# 4     Carnes de animais da espécie bovina, frescas o...     0.95988
# ...                                                 ...         ...
# 1106                  Antiguidades com mais de 100 anos     0.00100
# 1107                             Bagagem desacompanhada     0.01128
# 1108                                   Mala Diplomática     0.00725
# 1109  Consumo de bordo (exceto combustíveis e lubrif...    69.31955
# 1110                                              Total  1424.61316
#
#              AG         AN         AO           AR        AU        AW  \
# 0      0.000000   0.000000    0.00100     1.213100  0.001000  0.000000
# ...

# %%
pca = PCA(n_components=3)

# %%
df_T = df.drop("Mercadoria", axis=1).T
df_teste = df.drop("Mercadoria", axis=1)

# %%
pca.fit(df_T)
# Out:
# PCA(n_components=3)

# %%
v_lista = pca.components_
v_lista
# Out:
# array([[ 1.33789571e-06,  1.33789571e-06,  1.33789571e-06, ...,
#          1.65924680e-01,  2.45644815e-01,  9.33367243e-01],
#        [-4.00636460e-01, -1.63236479e-01, -1.38896581e-01, ...,
#          2.12896941e-03,  9.64269609e-02,  8.69317345e-01],
#        [-3.73845585e-01, -2.03097456e-01, -1.63247151e-01, ...,
#          4.67728316e-05,  2.47401753e-01,  8.41759734e-01]])

# %%
eigen_val = pca.explained_variance_
eigen_val
# Out:
# array([47451456.51388906,   835390.5189449 ,   157477.14514606])

# %%
v_lista
# Out:
# array([[ 1.90103805e-05,  6.75114468e-05,  1.66710793e-06, ...,
#          2.65162216e-06,  6.52492695e-02,  9.33367243e-01],
#        [-3.45260879e-05, -1.12623342e-04, -2.86057790e-06, ...,
#         -4.79472407e-06, -1.13534133e-01, -1.12108772e-01],
#        [-4.51513278e-05, -1.21577952e-04, -3.08698451e-06, ...,
#         -6.59638157e-06, -1.63247151e-01, -1.15307152e-01]])

# %%
v_lista.sort()
v_lista
# Out:
# array([[ 1.33789571e-06,  1.33789571e-06,  1.33789571e-06, ...,
#          1.65924680e-01,  2.45644815e-01,  9.33367243e-01],
#        [-4.00636460e-01, -1.63236479e-01, -1.38896581e-01, ...,
#          2.12896941e-03,  9.64269609e-02,  8.69317345e-01],
#        [-3.73845585e-01, -2.03097456e-01, -1.63247151e-01, ...,
#          4.67728316e-05,  2.47401753e-01,  8.41759734e-01]])

# %%
pca.get_feature_names_out()
# Out:
# array(['pca0', 'pca1', 'pca2'], dtype=object)

# %%
f_transformado = pca.fit_transform(df_T)
f_df = pd.DataFrame(f_transformado)
f_df = f_df.T
f_df.index = df["Mercadoria"][0:3]

# %%
f_df
# Out:
#                                                    0            1    \
# Mercadoria
# Cavalos, asininos e muares, vivos           315.627743 -1229.344833
# Animais vivos da espécie bovina            -277.609802    34.193853
# Animais vivos das espécies ovina e caprina -620.036840     1.882044
#
#                                                     2            3    \
# Mercadoria
# Cavalos, asininos e muares, vivos          -1227.355817 -1008.781639
# Animais vivos da espécie bovina               35.390448   -14.321834
# Animais vivos das espécies ovina e caprina     5.287495   -73.208063
#
#                                                    4            5    \
# Mercadoria
# Cavalos, asininos e muares, vivos           141.649169 -1237.176050
# Animais vivos da espécie bovina            -170.137985    36.605700
# Animais vivos das espécies ovina e caprina -169.557009     6.542815
#
#                                                     6           7    \
# Mercadoria
# ...

# %% [markdown]
# ## Teste

# %%
dataset_sk_arr = np.array([(1,7.3),(2,12.8),(3,16.8),(4,22.1),(5,27.9),(6,31.4),(7,36.8),(8,43.1)])

# %%
dt_temp1 = dataset_sk_arr[:, 0].copy()
dataset_sk_arr[:, 0] = dataset_sk_arr[:, 1]
dataset_sk_arr[:, 1] = dt_temp1
dataset_sk_arr
# Out:
# array([[ 7.3,  1. ],
#        [12.8,  2. ],
#        [16.8,  3. ],
#        [22.1,  4. ],
#        [27.9,  5. ],
#        [31.4,  6. ],
#        [36.8,  7. ],
#        [43.1,  8. ]])

# %%
pca_x = PCA(n_components=1)

# %%
pca_x.fit(dataset_sk_arr)
# Out:
# PCA(n_components=1)

# %%
pca_x.components_
# Out:
# array([[0.98068778, 0.19557986]])

# %%
pca_x.explained_variance_
# Out:
# array([156.49935999])

# %%
modelo = pca_x.transform(dataset_sk_arr)

# %%
modelo
# Out:
# array([[-17.82204843],
#        [-12.23268579],
#        [ -8.11435482],
#        [ -2.72112974],
#        [  3.16243924],
#        [  6.79042632],
#        [ 12.28172018],
#        [ 18.65563305]])
